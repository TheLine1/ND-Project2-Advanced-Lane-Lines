# %% [markdown]
# # Advanced-Lane-Lines
# Student: Martin Weissmann
# Datum : 15.05.2019

# %%
# %%html
# <img src="Bilder Notebook/Output_Img_Colored0.jpg", width=500>
# Out:
# <img src="Bilder Notebook/Output_Img_Colored0.jpg", width=500>

# %% [markdown]
# In this chapter we are focused on finding the lane lines in an image and later on test it on a video.
# This is now a more deeper way to find the lanes in the image.
# Short description of the way how I fixed it:
#
# 1. calibration of the camera
# 2. use gradient threshold
# 3. use color space threshold
# 4. combine the thresholds and find the best combination
# 5. define a Region of Interest – ROI
# 6. perspective transformation
# 7. find the lanes after the transformation
# 8. calculate the radius of the curvature
# 9. Plot the Image with the marked lanes and the the calculated values on it
# 10. define a pipeline to automate the process
#
# First we start with importing all important modules and the load the calibration values.
# #### **In function.py are some usefull functions for polting the images, ROI...**
# #### **FindingLane.py is a class with the necessary function for finding the lane lines**

# %%
import pickle
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import math
import function as fnc
import FindingLane as lane

#Read Image
def readIMG(img_name):
    image = mpimg.imread(img_name)
    shape = image.shape
    color_img = np.copy(image)    
    
    return color_img, shape

# read the calibration values ¶
dist_pickle = pickle.load( open("Camera_Calib_Values/wide_dist_pickle9Corner_class.p", "rb" ) )
mtx = dist_pickle["mtx"]
dist = dist_pickle["dist"]

# get test-image
color_img, shape = fnc.readIMG('test_images/straight_lines1.jpg')

line = lane.Lines()
line.set_cam_calib_param(mtx,dist)
undist_Img = line.undistort(color_img)

#plot Images
images=[color_img, undist_Img]
titels=['Original', 'Undistored IMG']
fnc.plot_n(images,titels,'gray')
# Out:
# raw =1.0

# %% [markdown]
# ### Let's try Canny Edge Detection

# %%
# Canny Edge Detection
low_threshold_canny  = 50 
high_threshold_canny = 150
sobel_kernel = 5
canny_binary = line.canny_edge(undist_Img,low_threshold_canny,high_threshold_canny,sobel_kernel,  True)

# %% [markdown]
# Canny Edge Detection is not the best option. Therefore we try
# - **gradient threshold**
# - **Magnitude of the Gradient**
# - **Direction of the gradient**
#
# Here we analyze each direction separate. The sobel operator make a convolution in X and Y direction.
#
# ### Calculation example:

# %%
# %%html
# <img src="Bilder Notebook/grad.png", width=300>
# <img src="Bilder Notebook/SobelBeisp.png", width=400>
# Out:
# <img src="Bilder Notebook/grad.png", width=300>
# <img src="Bilder Notebook/SobelBeisp.png", width=400>

# %% [markdown]
# ### Effects

# %%
# %%html
# <img src="Bilder Notebook/SobelBeispLösung.png", width=200>
# Out:
# <img src="Bilder Notebook/SobelBeispLösung.png", width=200>

# %% [markdown]
# ### Magnitude of the Gradient
#
# abs_sobelx=$ \sqrt{(sobel_x)^2}$
#
# abs_sobely=$\sqrt{(sobel_y)^2}$
#
# abs_sobelxy = $\sqrt{(sobel_x)^2+(sobel_y)^2}$
#
# ### Direction of the gradient
#
# $arctan(sobely​/sobelx​)$
#
#
# #### Info: A lot of the written functions have the possibility to switch the plot on and off. It's the parameter to the end -> True or False

# %%
ksize = 9
gradx = line.abs_sobel_thresh(undist_Img, orient='x', sobel_kernel=ksize, thresh=(30,220))
grady = line.abs_sobel_thresh(undist_Img, orient='y', sobel_kernel=ksize, thresh=(30, 220))

mag_binary = line.mag_thresh(undist_Img, sobel_kernel=ksize, mag_thresh=(30, 220))
dir_binary = line.dir_threshold(undist_Img, sobel_kernel=ksize, thresh=(0.6, 1.1))

combined = np.zeros_like(dir_binary)
combined[((gradx == 1) & (grady == 1)) | ((mag_binary == 1) & (dir_binary == 1))] = 1


images=[gradx, grady,mag_binary,dir_binary,combined]
titels=['Sobel X thresh', 'Sobel Y thresh','mag_binary','dir_binary','combined']
fnc.plot_n(images,titels,'gray')
# Out:
# raw =3.0

# %% [markdown]
# ## Color Space
#
# A color space is a specific organization of colors; color spaces provide a way to categorize colors and represent them in digital images.
#
# RGB is red-green-blue color space. You can think of this as a 3D space, in this case a cube, where any color can be represented by a 3D coordinate of R, G, and B values. For example, white has the coordinate (255, 255, 255), which has the maximum value for red, green, and blue.

# %%
# %%html
# <img src="Bilder Notebook/RGB.png", width=300>
# Out:
# <img src="Bilder Notebook/RGB.png", width=300>

# %% [markdown]
# ## HLS Space
#
# There is also **HSV color space (hue, saturation, and value), and HLS space (hue, lightness, and saturation)**. These are some of the most commonly used color spaces in image analysis. Here we use the HLS space

# %%
# %%html
# <img src="Bilder Notebook/HLS.png", width=300>
# Out:
# <img src="Bilder Notebook/HLS.png", width=300>

# %%
# -------------- Color Spaces ---------------------
#Binary Threshold
bin_thresh = (180, 255)
binary_img = line.binary_thresh(undist_Img, bin_thresh,True)

#RGB Thresh
rgb_thresh = (200, 255)
R_binary = line.rgb_thresh(undist_Img,rgb_thresh,True)

#HLS Thresh
thresh_hLs = (90, 255)
thresh_Hls = (15, 100)
hls_thresh = thresh_hLs + thresh_Hls
hls_s_binary, hls_h_binary  = line.hls_thresh(undist_Img, hls_thresh,True)

# %% [markdown]
# ### Combination of the all variants

# %%
combined = np.zeros_like(dir_binary)
combined[((gradx == 1) & (grady == 1)) | ((mag_binary == 1) & (dir_binary == 1))] = 1

combined_Color = np.zeros_like(R_binary)
combined_Color[((hls_s_binary == 1) & (hls_h_binary == 1)) | (R_binary == 1)] = 1

combined_beide = np.zeros_like(combined_Color)
combined_beide[((combined_Color == 1) | (combined == 1))] = 1


images=[binary_img,R_binary,hls_s_binary, hls_h_binary, combined_Color,combined_beide ]
titels=['Binary Thresh','RGB Thresh','HLS -S- Thresh','HLS -H- Thresh', 'combined_Color','combined_both']
fnc.plot_n(images,titels,'gray')
# Out:
# raw =3.0

# %% [markdown]
# ## Combination Pipline
#
# This is a pipline with the outcome of the best combination result.

# %%
##----------------------Sobel Threshold 
sobel_thresh = (30,220)
mag_thresh   = (30, 220)
dir_thresh   = (0.6, 1.1)
bin_thresh   = (180, 255)
rgb_thresh   = (200, 255)
hls_L_thresh = (90, 255)
hls_H_thresh = (15, 100)
hls_thresh = hls_L_thresh + hls_H_thresh

thresh = [sobel_thresh, mag_thresh, dir_thresh, bin_thresh, \
          rgb_thresh, hls_thresh]
ksize = 9
binary_best_combi = line.pipline_combination(undist_Img, ksize, thresh, False)

images=[undist_Img,binary_best_combi]
titels=['Original IMG','Binary Best Combination']
fnc.plot_n(images,titels,'gray')
# Out:
# raw =1.0

# %% [markdown]
# ## Region of Interest
#
# Define a Region of Interest (Polygon) like in the folloing image. The y_line is how far away the view should be. The function for that is in function.py included.

# %%
# %%html
# <img src="Bilder Notebook/ROI_marked.png", width=400>
# Out:
# <img src="Bilder Notebook/ROI_marked.png", width=400>

# %%
# ROI - Four Side Polygone -> polygon_roi(img, imshape, y_line, x_left, x_right, rgb_threshold)      
roi_color_undist_Img = np.copy(undist_Img)

img_shape_y = shape[0]
ima_shape_x = shape[1]

y_line  = img_shape_y - 260

x_left  = ima_shape_x - 715
x_right = ima_shape_x - 560

bottom_left  = 90
bottom_right = ima_shape_x - 90

vertices, roi_marked_img = fnc.polygon_roi_color(roi_color_undist_Img,bottom_left, bottom_right,y_line, x_left, x_right, True)
# Out:
# Vertices.shape(1, 4, 2)

# %% [markdown]
# ## Perspective Transformation
#
# Now the ROI is defined, so we can warp the ROI as follows.

# %%
warped = line.perspective_transform(undist_Img, vertices)

#plt.imshow(warped)

images=[undist_Img,warped]
titels=['Original','warped']
fnc.plot_n(images,titels,'gray')
# Out:
# raw =1.0

# %% [markdown]
# ## Test with an image on the combined pipline

# %%
# Warpe the Image 
# for Binary Image
roi_color_undist_Img_bin = np.copy(undist_Img)

sobel_thresh = (30,220)
mag_thresh   = (30, 220)
dir_thresh   = (0.6, 1.1)
bin_thresh   = (180, 255)
rgb_thresh   = (200, 255)
hls_L_thresh = (90, 255)
hls_H_thresh = (15, 100)
hls_thresh = hls_L_thresh + hls_H_thresh

thresh = [sobel_thresh, mag_thresh, dir_thresh, bin_thresh, \
          rgb_thresh, hls_thresh]
ksize = 9
binary_best_combi = line.pipline_combination(roi_color_undist_Img_bin, ksize, thresh, False)

vertices = fnc.polygon_roi_binary(binary_best_combi,bottom_left, bottom_right,y_line, x_left, x_right)
warped_bin = line.perspective_transform(binary_best_combi, vertices)

plt.imshow(undist_Img)

images=[binary_best_combi,warped_bin]
titels=['Best Binary Combination','Warped Binary Image']
fnc.plot_n(images,titels,'gray')
# Out:
# raw =1.0

# %% [markdown]
# ## Histogram
#
# With the histogram it is possible to find the lane lines in the image. For further analysis we get now a start point of the lanes in the image.

# %%
# Histogram
histogram =  line.hist(warped_bin, True)

# %% [markdown]
# ## Sliding Window and find the Lanes with a Polynominal
#
# We can use the two highest peaks from our histogram as a starting point for determining where the lane lines are, and then use sliding windows moving upward in the image (further along the road) to determine where the lane lines go.
#
# #### Set up windows and window hyperparameters
#
# Next step is to set a few hyperparameters related to our sliding windows, and set them up to iterate across the binary activations in the image.
#
# ## Fit a polynomial
#
# Now that we have found all our pixels belonging to each line through the sliding window method, it's time to fit a polynomial to the line like:
#
# $ f(y)=Ay^2+By+C $
#
# The used function and the implementation is in FindingLane.py.

# %%
# %%html
# <img src="Bilder Notebook/Sliding Window.png", width=400>
# %%html
# <img src="Bilder Notebook/R_Kurve.jpg", width=400>
# Out:
# <img src="Bilder Notebook/Sliding Window.png", width=400>
# %%html
# <img src="Bilder Notebook/R_Kurve.jpg", width=400>

# %%
# HYPERPARAMETERS
# Choose the number of sliding windows
nwindows = 9
# Set the width of the windows +/- margin
margin = 100
# Set minimum number of pixels found to recenter window
minpix = 50

find_pixel_out_img = line.find_pixels(warped_bin, nwindows, margin, minpix, True)
ployfit_out_img = line.fit_polinominal(find_pixel_out_img,find_pixel_out_img, True)

# %% [markdown]
# ## Calculation of Radius from the Curvature
#
# Next step is to calculate the Radius of the Curvature and the Out of Center value.
# The Radius can be calculated like this:

# %%
# %%html
# <img src="Bilder Notebook/R_Formel_aufl.png", width=200>
# Out:
# <img src="Bilder Notebook/R_Formel_aufl.png", width=200>

# %%
ooc = line.calc_curvature_ooc(warped_bin)
print('left_curv: ' + str(line.left_curverad) + 'm' 
     'right_curv: ' + str(line.right_curverad) + 'm')
print('OOC: ' + str(ooc))
undist_Img_copy = np.copy(undist_Img)

# Draw lane on Original Image
colerd_lane_img = line.draw_lane_on_image(undist_Img_copy,warped_bin)

img_text = "Radius of curvature: " + str(round((line.left_curverad + line.right_curverad)/2,2)) + ' (m)'

if ooc<+ 0:
    img_text2 = "Vehicle is: " + str(round(np.abs(ooc),2)) + ' (m) left of center'
else:
    img_text2 = "Vehicle is: " + str(round(np.abs(ooc),2)) + ' (m) right of center'
 
cv2.putText(colerd_lane_img, img_text, (40, 70), cv2.FONT_HERSHEY_DUPLEX, 1.5, (255, 255, 255), 2)
cv2.putText(colerd_lane_img, img_text2, (40, 140), cv2.FONT_HERSHEY_DUPLEX, 1.5, (255, 255, 255), 2)

plt.imshow(colerd_lane_img)
plt.show()
# Out:
# left_curv: 293009.7325514635mright_curv: 7355.1693173156955m
# OOC: 0.0008468938464553875

# %% [markdown]
# ## Pipeline
#
# This is a summery of the used function in one pipline.

# %%
def pipeline(undist_Img, plot_flag):
    
    #####Sobel Threshold 
    sobel_thresh = (30,220)
    mag_thresh   = (30, 220)
    dir_thresh   = (0.6, 1.1)
    bin_thresh   = (180, 255)
    rgb_thresh   = (200, 255)
    hls_L_thresh = (90, 255)
    hls_H_thresh = (15, 100)
    hls_thresh = hls_L_thresh + hls_H_thresh

    thresh = [sobel_thresh, mag_thresh, dir_thresh, bin_thresh, \
              rgb_thresh, hls_thresh]
    ksize = 9
    binary_best_combi = line.pipline_combination(undist_Img, ksize, thresh, plot_flag)

    # ROI - Four Side Polygone -> polygon_roi(img, imshape, y_line, x_left, x_right, rgb_threshold)      
    img_shape_y = binary_best_combi.shape[0]
    ima_shape_x = binary_best_combi.shape[1]
    y_line  = img_shape_y - 275
    x_left  = ima_shape_x - 675
    x_right = ima_shape_x - 610
    bottom_left  = 180
    bottom_right = ima_shape_x - 150 
    
    # for Binary Image
    vertices = fnc.polygon_roi_binary(binary_best_combi,bottom_left, bottom_right,y_line, x_left, x_right)
    warped_bin = line.perspective_transform(binary_best_combi, vertices)
    
    # Histogram
    histogram =  line.hist(warped_bin, plot_flag)
    
    # HYPERPARAMETERS
    # Choose the number of sliding windows
    nwindows = 9
    # Set the width of the windows +/- margin
    margin = 100
    # Set minimum number of pixels found to recenter window
    minpix = 50
    out = line.find_pixels(warped_bin, nwindows, margin, minpix, plot_flag)
    ployfit_out_img = line.fit_polinominal(warped_bin, out, plot_flag)
    
    # Calc Curvature
    ooc = line.calc_curvature_ooc(warped_bin)
    undist_Img_copy = np.copy(undist_Img)
    
    # Draw lane on Original Image
    colerd_lane_img = line.draw_lane_on_image(undist_Img_copy,warped_bin)
    colerd_lane_img.astype(np.uint8)
    img_text = "Radius of curvature: " + str(round((line.left_curverad + line.right_curverad)/2)) + ' (m)'

    if ooc<+ 0:
        img_text2 = "Vehicle is: " + str(round(np.abs(ooc),2)) + ' (m) left of center'
    else:
        img_text2 = "Vehicle is: " + str(round(np.abs(ooc),2)) + ' (m) right of center'


    cv2.putText(colerd_lane_img, img_text, (40, 70), cv2.FONT_HERSHEY_DUPLEX, 1.5, (255, 255, 255), 2)
    cv2.putText(colerd_lane_img, img_text2, (40, 140), cv2.FONT_HERSHEY_DUPLEX, 1.5, (255, 255, 255), 2)
    
    return colerd_lane_img

# %% [markdown]
# ## Test the Pipline with different images

# %%
import pickle
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import math
import function as fnc
import FindingLane as lane
import scipy.misc
# %matplotlib inline

# Read in the saved camera matrix and distortion coefficients
# These are the arrays you calculated using cv2.calibrateCamera()
dist_pickle = pickle.load( open("Camera_Calib_Values/wide_dist_pickle9Corner_class.p", "rb" ) )
mtx = dist_pickle["mtx"]
dist = dist_pickle["dist"]

images = glob.glob('test_images/TestPipline/*.jpg')

for idx, fname in enumerate(images):
    color_img, shape = fnc.readIMG(fname)

    line = lane.Lines()
    line.set_cam_calib_param(mtx,dist)

    undist_Img = line.undistort(color_img)
    outputIMG = pipeline(undist_Img, None)
    plt.imshow(outputIMG)
    plt.show()
    
    # Save Image
    #write_name = 'output_images/Colored_Lane_Measured/Output_Img_Colored' + str(idx)+'.jpg'
    #scipy.misc.imsave(write_name, outputIMG)

# %% [markdown]
# ## Test on a video

# %%
import pickle
import glob
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import math
import function as fnc
import FindingLane as lane
import scipy.misc

# %matplotlib inline

def image_pipeline(img):
    # Read in the saved camera matrix and distortion coefficients
    # These are the arrays you calculated using cv2.calibrateCamera()
    dist_pickle = pickle.load( open("Camera_Calib_Values/wide_dist_pickle9Corner_class.p", "rb" ) )
    mtx = dist_pickle["mtx"]
    dist = dist_pickle["dist"]

    #line = lane.Lines()
    line.set_cam_calib_param(mtx,dist)

    undist_Img = line.undistort(img)
    outputIMG = pipeline(undist_Img, None)
    
    return outputIMG

# %%
from moviepy.editor import VideoFileClip
from IPython.display import HTML
#my_clip.write_gif('test.gif', fps=12)
line = lane.Lines()
video_output1 = 'project_video_output4.mp4'
video_input1 = VideoFileClip('project_video.mp4')#.subclip(22,26)

processed_video = video_input1.fl_image(image_pipeline)
# %time processed_video.write_videofile(video_output1, audio=False)
# Out:
# t:   0%|          | 0/1260 [00:00<?, ?it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# Moviepy - Building video project_video_output4.mp4.
# Moviepy - Writing video project_video_output4.mp4
# t:   0%|          | 2/1260 [00:00<03:52,  5.42it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   0%|          | 3/1260 [00:00<05:17,  3.96it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   0%|          | 4/1260 [00:01<05:57,  3.51it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   0%|          | 5/1260 [00:01<06:35,  3.18it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   0%|          | 6/1260 [00:01<06:54,  3.02it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   1%|          | 7/1260 [00:02<07:14,  2.88it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   1%|          | 8/1260 [00:02<07:19,  2.85it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   1%|          | 9/1260 [00:02<07:21,  2.84it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   1%|          | 10/1260 [00:03<07:24,  2.81it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   1%|          | 11/1260 [00:03<07:21,  2.83it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   1%|          | 12/1260 [00:04<07:23,  2.81it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   1%|          | 13/1260 [00:04<07:24,  2.80it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   1%|          | 14/1260 [00:04<07:34,  2.74it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   1%|          | 15/1260 [00:05<07:45,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   1%|▏         | 16/1260 [00:05<07:53,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   1%|▏         | 17/1260 [00:06<08:01,  2.58it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   1%|▏         | 18/1260 [00:06<08:00,  2.59it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   2%|▏         | 19/1260 [00:06<07:51,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   2%|▏         | 20/1260 [00:07<07:44,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   2%|▏         | 21/1260 [00:07<07:41,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   2%|▏         | 22/1260 [00:07<08:31,  2.42it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   2%|▏         | 23/1260 [00:08<08:31,  2.42it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   2%|▏         | 24/1260 [00:08<08:37,  2.39it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   2%|▏         | 25/1260 [00:09<08:16,  2.49it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   2%|▏         | 26/1260 [00:09<08:05,  2.54it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   2%|▏         | 27/1260 [00:09<07:49,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   2%|▏         | 28/1260 [00:10<07:48,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   2%|▏         | 29/1260 [00:10<07:48,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   2%|▏         | 30/1260 [00:11<07:41,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   2%|▏         | 31/1260 [00:11<07:40,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   3%|▎         | 32/1260 [00:11<07:37,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   3%|▎         | 33/1260 [00:12<07:35,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   3%|▎         | 34/1260 [00:12<08:04,  2.53it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   3%|▎         | 35/1260 [00:12<07:48,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   3%|▎         | 36/1260 [00:13<07:36,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   3%|▎         | 37/1260 [00:13<07:37,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   3%|▎         | 38/1260 [00:14<07:40,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   3%|▎         | 39/1260 [00:14<07:41,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   3%|▎         | 40/1260 [00:14<07:36,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   3%|▎         | 41/1260 [00:15<07:37,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   3%|▎         | 42/1260 [00:15<07:34,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   3%|▎         | 43/1260 [00:15<07:32,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   3%|▎         | 44/1260 [00:16<07:56,  2.55it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   4%|▎         | 45/1260 [00:16<08:03,  2.51it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   4%|▎         | 46/1260 [00:17<07:50,  2.58it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   4%|▎         | 47/1260 [00:17<07:44,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   4%|▍         | 48/1260 [00:17<07:34,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   4%|▍         | 49/1260 [00:18<07:29,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   4%|▍         | 50/1260 [00:18<07:29,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   4%|▍         | 51/1260 [00:18<07:28,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   4%|▍         | 52/1260 [00:19<07:31,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   4%|▍         | 53/1260 [00:19<07:34,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   4%|▍         | 54/1260 [00:20<07:33,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   4%|▍         | 55/1260 [00:20<07:30,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   4%|▍         | 56/1260 [00:20<07:21,  2.73it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   5%|▍         | 57/1260 [00:21<07:18,  2.75it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   5%|▍         | 58/1260 [00:21<07:24,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   5%|▍         | 59/1260 [00:21<07:22,  2.72it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   5%|▍         | 60/1260 [00:22<07:19,  2.73it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   5%|▍         | 61/1260 [00:22<07:24,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   5%|▍         | 62/1260 [00:23<07:30,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   5%|▌         | 63/1260 [00:23<07:23,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   5%|▌         | 64/1260 [00:23<07:24,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   5%|▌         | 65/1260 [00:24<07:22,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   5%|▌         | 66/1260 [00:24<07:18,  2.72it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   5%|▌         | 67/1260 [00:24<07:31,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   5%|▌         | 68/1260 [00:25<07:24,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   5%|▌         | 69/1260 [00:25<07:26,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   6%|▌         | 70/1260 [00:26<07:34,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   6%|▌         | 71/1260 [00:26<07:30,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   6%|▌         | 72/1260 [00:26<07:25,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   6%|▌         | 73/1260 [00:27<07:24,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   6%|▌         | 74/1260 [00:27<07:26,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   6%|▌         | 75/1260 [00:27<07:21,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   6%|▌         | 76/1260 [00:28<07:23,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   6%|▌         | 77/1260 [00:28<07:19,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   6%|▌         | 78/1260 [00:29<07:46,  2.53it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   6%|▋         | 79/1260 [00:29<07:45,  2.54it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   6%|▋         | 80/1260 [00:29<07:28,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   6%|▋         | 81/1260 [00:30<07:27,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   7%|▋         | 82/1260 [00:30<07:21,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   7%|▋         | 83/1260 [00:30<07:19,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   7%|▋         | 84/1260 [00:31<07:16,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   7%|▋         | 85/1260 [00:31<07:14,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   7%|▋         | 86/1260 [00:32<07:13,  2.71it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   7%|▋         | 87/1260 [00:32<07:12,  2.71it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   7%|▋         | 88/1260 [00:32<07:18,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   7%|▋         | 89/1260 [00:33<07:19,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   7%|▋         | 90/1260 [00:33<07:18,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   7%|▋         | 91/1260 [00:33<07:15,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   7%|▋         | 92/1260 [00:34<07:16,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   7%|▋         | 93/1260 [00:34<07:11,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   7%|▋         | 94/1260 [00:35<07:12,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   8%|▊         | 95/1260 [00:35<07:14,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   8%|▊         | 96/1260 [00:35<07:22,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   8%|▊         | 97/1260 [00:36<07:23,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   8%|▊         | 98/1260 [00:36<07:21,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   8%|▊         | 99/1260 [00:36<07:11,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   8%|▊         | 100/1260 [00:37<07:18,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   8%|▊         | 101/1260 [00:37<07:11,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   8%|▊         | 102/1260 [00:38<07:15,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   8%|▊         | 103/1260 [00:38<07:18,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   8%|▊         | 104/1260 [00:38<07:15,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   8%|▊         | 105/1260 [00:39<07:15,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   8%|▊         | 106/1260 [00:39<07:17,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   8%|▊         | 107/1260 [00:39<07:15,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   9%|▊         | 108/1260 [00:40<07:08,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   9%|▊         | 109/1260 [00:40<07:37,  2.52it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   9%|▊         | 110/1260 [00:41<07:25,  2.58it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   9%|▉         | 111/1260 [00:41<07:19,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   9%|▉         | 112/1260 [00:41<07:08,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   9%|▉         | 113/1260 [00:42<07:11,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   9%|▉         | 114/1260 [00:42<07:09,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   9%|▉         | 115/1260 [00:43<07:12,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   9%|▉         | 116/1260 [00:43<07:10,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   9%|▉         | 117/1260 [00:43<07:10,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   9%|▉         | 118/1260 [00:44<07:15,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:   9%|▉         | 119/1260 [00:44<07:07,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  10%|▉         | 120/1260 [00:44<07:15,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  10%|▉         | 121/1260 [00:45<07:09,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  10%|▉         | 122/1260 [00:45<07:02,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  10%|▉         | 123/1260 [00:46<07:04,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  10%|▉         | 124/1260 [00:46<07:09,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  10%|▉         | 125/1260 [00:46<07:02,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  10%|█         | 126/1260 [00:47<06:57,  2.72it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  10%|█         | 127/1260 [00:47<06:57,  2.72it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  10%|█         | 128/1260 [00:47<06:56,  2.72it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  10%|█         | 129/1260 [00:48<06:53,  2.73it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  10%|█         | 130/1260 [00:48<06:55,  2.72it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  10%|█         | 131/1260 [00:48<06:58,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  10%|█         | 132/1260 [00:49<06:54,  2.72it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  11%|█         | 133/1260 [00:49<06:59,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  11%|█         | 134/1260 [00:50<06:54,  2.72it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  11%|█         | 135/1260 [00:50<06:51,  2.73it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  11%|█         | 136/1260 [00:50<06:46,  2.76it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  11%|█         | 137/1260 [00:51<06:48,  2.75it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  11%|█         | 138/1260 [00:51<06:53,  2.71it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  11%|█         | 139/1260 [00:51<06:54,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  11%|█         | 140/1260 [00:52<06:53,  2.71it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  11%|█         | 141/1260 [00:52<06:56,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  11%|█▏        | 142/1260 [00:53<06:50,  2.72it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  11%|█▏        | 143/1260 [00:53<06:59,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  11%|█▏        | 144/1260 [00:53<06:56,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  12%|█▏        | 145/1260 [00:54<07:02,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  12%|█▏        | 146/1260 [00:54<06:56,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  12%|█▏        | 147/1260 [00:54<06:59,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  12%|█▏        | 148/1260 [00:55<06:56,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  12%|█▏        | 149/1260 [00:55<06:55,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  12%|█▏        | 150/1260 [00:56<06:51,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  12%|█▏        | 151/1260 [00:56<06:48,  2.71it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  12%|█▏        | 152/1260 [00:56<06:51,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  12%|█▏        | 153/1260 [00:57<06:47,  2.71it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  12%|█▏        | 154/1260 [00:57<06:55,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  12%|█▏        | 155/1260 [00:57<07:03,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  12%|█▏        | 156/1260 [00:58<06:58,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  12%|█▏        | 157/1260 [00:58<06:48,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  13%|█▎        | 158/1260 [00:59<06:49,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  13%|█▎        | 159/1260 [00:59<06:49,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  13%|█▎        | 160/1260 [00:59<06:51,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  13%|█▎        | 161/1260 [01:00<06:47,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  13%|█▎        | 162/1260 [01:00<06:46,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  13%|█▎        | 163/1260 [01:00<06:50,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  13%|█▎        | 164/1260 [01:01<06:47,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  13%|█▎        | 165/1260 [01:01<06:50,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  13%|█▎        | 166/1260 [01:01<06:45,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  13%|█▎        | 167/1260 [01:02<06:41,  2.72it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  13%|█▎        | 168/1260 [01:02<06:42,  2.71it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  13%|█▎        | 169/1260 [01:03<06:46,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  13%|█▎        | 170/1260 [01:03<06:48,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  14%|█▎        | 171/1260 [01:03<07:15,  2.50it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  14%|█▎        | 172/1260 [01:04<07:02,  2.57it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  14%|█▎        | 173/1260 [01:04<07:14,  2.50it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  14%|█▍        | 174/1260 [01:05<07:01,  2.58it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  14%|█▍        | 175/1260 [01:05<07:00,  2.58it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  14%|█▍        | 176/1260 [01:05<06:54,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  14%|█▍        | 177/1260 [01:06<06:50,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  14%|█▍        | 178/1260 [01:06<06:51,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  14%|█▍        | 179/1260 [01:06<06:53,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  14%|█▍        | 180/1260 [01:07<07:05,  2.54it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  14%|█▍        | 181/1260 [01:07<07:01,  2.56it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  14%|█▍        | 182/1260 [01:08<06:57,  2.58it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  15%|█▍        | 183/1260 [01:08<06:56,  2.59it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  15%|█▍        | 184/1260 [01:08<06:46,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  15%|█▍        | 185/1260 [01:09<06:53,  2.60it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  15%|█▍        | 186/1260 [01:09<06:50,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  15%|█▍        | 187/1260 [01:10<06:51,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  15%|█▍        | 188/1260 [01:10<06:48,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  15%|█▌        | 189/1260 [01:10<06:42,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  15%|█▌        | 190/1260 [01:11<06:40,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  15%|█▌        | 191/1260 [01:11<06:35,  2.71it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  15%|█▌        | 192/1260 [01:11<06:36,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  15%|█▌        | 193/1260 [01:12<06:35,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  15%|█▌        | 194/1260 [01:12<06:39,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  15%|█▌        | 195/1260 [01:13<06:49,  2.60it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  16%|█▌        | 196/1260 [01:13<06:53,  2.58it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  16%|█▌        | 197/1260 [01:13<06:47,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  16%|█▌        | 198/1260 [01:14<06:42,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  16%|█▌        | 199/1260 [01:14<06:50,  2.58it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  16%|█▌        | 200/1260 [01:14<06:46,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  16%|█▌        | 201/1260 [01:15<06:51,  2.58it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  16%|█▌        | 202/1260 [01:15<06:46,  2.60it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  16%|█▌        | 203/1260 [01:16<06:45,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  16%|█▌        | 204/1260 [01:16<06:44,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  16%|█▋        | 205/1260 [01:16<06:41,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  16%|█▋        | 206/1260 [01:17<06:38,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  16%|█▋        | 207/1260 [01:17<06:43,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  17%|█▋        | 208/1260 [01:18<06:37,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  17%|█▋        | 209/1260 [01:18<06:32,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  17%|█▋        | 210/1260 [01:18<06:31,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  17%|█▋        | 211/1260 [01:19<06:34,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  17%|█▋        | 212/1260 [01:19<06:33,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  17%|█▋        | 213/1260 [01:19<06:35,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  17%|█▋        | 214/1260 [01:20<06:40,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  17%|█▋        | 215/1260 [01:20<06:42,  2.60it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  17%|█▋        | 216/1260 [01:21<06:38,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  17%|█▋        | 217/1260 [01:21<06:41,  2.60it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  17%|█▋        | 218/1260 [01:21<06:47,  2.56it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  17%|█▋        | 219/1260 [01:22<06:38,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  17%|█▋        | 220/1260 [01:22<06:35,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  18%|█▊        | 221/1260 [01:22<06:36,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  18%|█▊        | 222/1260 [01:23<06:36,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  18%|█▊        | 223/1260 [01:23<06:37,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  18%|█▊        | 224/1260 [01:24<06:34,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  18%|█▊        | 225/1260 [01:24<06:32,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  18%|█▊        | 226/1260 [01:24<06:45,  2.55it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  18%|█▊        | 227/1260 [01:25<06:48,  2.53it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  18%|█▊        | 228/1260 [01:25<06:40,  2.58it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  18%|█▊        | 229/1260 [01:26<06:30,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  18%|█▊        | 230/1260 [01:26<06:34,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  18%|█▊        | 231/1260 [01:26<06:29,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  18%|█▊        | 232/1260 [01:27<06:27,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  18%|█▊        | 233/1260 [01:27<06:23,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  19%|█▊        | 234/1260 [01:27<06:23,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  19%|█▊        | 235/1260 [01:28<06:33,  2.60it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  19%|█▊        | 236/1260 [01:28<06:28,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  19%|█▉        | 237/1260 [01:29<06:36,  2.58it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  19%|█▉        | 238/1260 [01:29<07:37,  2.23it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  19%|█▉        | 239/1260 [01:30<07:28,  2.28it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  19%|█▉        | 240/1260 [01:30<08:26,  2.01it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  19%|█▉        | 241/1260 [01:31<07:53,  2.15it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  19%|█▉        | 242/1260 [01:31<07:22,  2.30it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  19%|█▉        | 243/1260 [01:31<07:04,  2.40it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  19%|█▉        | 244/1260 [01:32<06:48,  2.49it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  19%|█▉        | 245/1260 [01:32<06:36,  2.56it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  20%|█▉        | 246/1260 [01:33<06:32,  2.58it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  20%|█▉        | 247/1260 [01:33<06:27,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  20%|█▉        | 248/1260 [01:33<06:19,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  20%|█▉        | 249/1260 [01:34<06:17,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  20%|█▉        | 250/1260 [01:34<06:17,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  20%|█▉        | 251/1260 [01:34<06:17,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  20%|██        | 252/1260 [01:35<06:12,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  20%|██        | 253/1260 [01:35<06:09,  2.72it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  20%|██        | 254/1260 [01:35<06:12,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  20%|██        | 255/1260 [01:36<06:14,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  20%|██        | 256/1260 [01:36<06:12,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  20%|██        | 257/1260 [01:37<06:13,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  20%|██        | 258/1260 [01:37<06:08,  2.72it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  21%|██        | 259/1260 [01:37<06:16,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  21%|██        | 260/1260 [01:38<06:14,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  21%|██        | 261/1260 [01:38<06:14,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  21%|██        | 262/1260 [01:38<06:16,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  21%|██        | 263/1260 [01:39<06:15,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  21%|██        | 264/1260 [01:39<06:10,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  21%|██        | 265/1260 [01:40<06:07,  2.71it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  21%|██        | 266/1260 [01:40<06:09,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  21%|██        | 267/1260 [01:40<06:04,  2.72it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  21%|██▏       | 268/1260 [01:41<06:08,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  21%|██▏       | 269/1260 [01:41<06:04,  2.72it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  21%|██▏       | 270/1260 [01:41<06:06,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  22%|██▏       | 271/1260 [01:42<06:06,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  22%|██▏       | 272/1260 [01:42<06:12,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  22%|██▏       | 273/1260 [01:43<06:14,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  22%|██▏       | 274/1260 [01:43<06:18,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  22%|██▏       | 275/1260 [01:43<06:13,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  22%|██▏       | 276/1260 [01:44<06:13,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  22%|██▏       | 277/1260 [01:44<06:08,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  22%|██▏       | 278/1260 [01:44<06:11,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  22%|██▏       | 279/1260 [01:45<06:07,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  22%|██▏       | 280/1260 [01:45<06:17,  2.59it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  22%|██▏       | 281/1260 [01:46<06:10,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  22%|██▏       | 282/1260 [01:46<06:06,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  22%|██▏       | 283/1260 [01:46<06:07,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  23%|██▎       | 284/1260 [01:47<06:03,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  23%|██▎       | 285/1260 [01:47<06:01,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  23%|██▎       | 286/1260 [01:47<06:01,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  23%|██▎       | 287/1260 [01:48<06:11,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  23%|██▎       | 288/1260 [01:48<06:02,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  23%|██▎       | 289/1260 [01:49<06:07,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  23%|██▎       | 290/1260 [01:49<06:02,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  23%|██▎       | 291/1260 [01:49<06:03,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  23%|██▎       | 292/1260 [01:50<06:07,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  23%|██▎       | 293/1260 [01:50<07:04,  2.28it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  23%|██▎       | 294/1260 [01:51<06:55,  2.33it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  23%|██▎       | 295/1260 [01:51<06:43,  2.39it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  23%|██▎       | 296/1260 [01:51<06:29,  2.48it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  24%|██▎       | 297/1260 [01:52<06:20,  2.53it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  24%|██▎       | 298/1260 [01:52<06:19,  2.53it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  24%|██▎       | 299/1260 [01:53<07:24,  2.16it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  24%|██▍       | 300/1260 [01:54<08:25,  1.90it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  24%|██▍       | 301/1260 [01:54<09:10,  1.74it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  24%|██▍       | 302/1260 [01:55<09:21,  1.71it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  24%|██▍       | 303/1260 [01:55<08:24,  1.90it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  24%|██▍       | 304/1260 [01:56<07:59,  1.99it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  24%|██▍       | 305/1260 [01:56<07:30,  2.12it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  24%|██▍       | 306/1260 [01:56<07:04,  2.25it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  24%|██▍       | 307/1260 [01:57<06:42,  2.37it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  24%|██▍       | 308/1260 [01:57<06:24,  2.47it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  25%|██▍       | 309/1260 [01:58<06:16,  2.53it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  25%|██▍       | 310/1260 [01:58<06:14,  2.53it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  25%|██▍       | 311/1260 [01:58<06:06,  2.59it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  25%|██▍       | 312/1260 [01:59<06:07,  2.58it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  25%|██▍       | 313/1260 [01:59<05:59,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  25%|██▍       | 314/1260 [01:59<05:54,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  25%|██▌       | 315/1260 [02:00<05:55,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  25%|██▌       | 316/1260 [02:00<05:59,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  25%|██▌       | 317/1260 [02:01<06:00,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  25%|██▌       | 318/1260 [02:01<06:00,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  25%|██▌       | 319/1260 [02:01<06:07,  2.56it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  25%|██▌       | 320/1260 [02:02<06:00,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  25%|██▌       | 321/1260 [02:02<05:57,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  26%|██▌       | 322/1260 [02:02<05:55,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  26%|██▌       | 323/1260 [02:03<05:50,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  26%|██▌       | 324/1260 [02:03<05:47,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  26%|██▌       | 325/1260 [02:04<05:42,  2.73it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  26%|██▌       | 326/1260 [02:04<05:45,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  26%|██▌       | 327/1260 [02:04<05:46,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  26%|██▌       | 328/1260 [02:05<05:46,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  26%|██▌       | 329/1260 [02:05<05:47,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  26%|██▌       | 330/1260 [02:05<05:53,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  26%|██▋       | 331/1260 [02:06<05:48,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# ...
# t:  92%|█████████▏| 1153/1260 [07:21<00:39,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  92%|█████████▏| 1154/1260 [07:22<00:39,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  92%|█████████▏| 1155/1260 [07:22<00:40,  2.58it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  92%|█████████▏| 1156/1260 [07:23<00:40,  2.59it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  92%|█████████▏| 1157/1260 [07:23<00:38,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  92%|█████████▏| 1158/1260 [07:23<00:37,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  92%|█████████▏| 1159/1260 [07:24<00:37,  2.71it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  92%|█████████▏| 1160/1260 [07:24<00:36,  2.74it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  92%|█████████▏| 1161/1260 [07:24<00:36,  2.72it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  92%|█████████▏| 1162/1260 [07:25<00:36,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  92%|█████████▏| 1163/1260 [07:25<00:37,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  92%|█████████▏| 1164/1260 [07:25<00:36,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  92%|█████████▏| 1165/1260 [07:26<00:35,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  93%|█████████▎| 1166/1260 [07:26<00:35,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  93%|█████████▎| 1167/1260 [07:27<00:34,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  93%|█████████▎| 1168/1260 [07:27<00:34,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  93%|█████████▎| 1169/1260 [07:27<00:34,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  93%|█████████▎| 1170/1260 [07:28<00:34,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  93%|█████████▎| 1171/1260 [07:28<00:33,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  93%|█████████▎| 1172/1260 [07:28<00:33,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  93%|█████████▎| 1173/1260 [07:29<00:32,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  93%|█████████▎| 1174/1260 [07:29<00:32,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  93%|█████████▎| 1175/1260 [07:30<00:32,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  93%|█████████▎| 1176/1260 [07:30<00:32,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  93%|█████████▎| 1177/1260 [07:30<00:31,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  93%|█████████▎| 1178/1260 [07:31<00:31,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  94%|█████████▎| 1179/1260 [07:31<00:30,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  94%|█████████▎| 1180/1260 [07:32<00:30,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  94%|█████████▎| 1181/1260 [07:32<00:30,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  94%|█████████▍| 1182/1260 [07:32<00:29,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  94%|█████████▍| 1183/1260 [07:33<00:29,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  94%|█████████▍| 1184/1260 [07:33<00:29,  2.57it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  94%|█████████▍| 1185/1260 [07:33<00:29,  2.58it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  94%|█████████▍| 1186/1260 [07:34<00:28,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  94%|█████████▍| 1187/1260 [07:34<00:28,  2.57it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  94%|█████████▍| 1188/1260 [07:35<00:32,  2.20it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  94%|█████████▍| 1189/1260 [07:35<00:35,  1.99it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  94%|█████████▍| 1190/1260 [07:36<00:37,  1.88it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  95%|█████████▍| 1191/1260 [07:36<00:34,  2.02it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  95%|█████████▍| 1192/1260 [07:37<00:31,  2.16it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  95%|█████████▍| 1193/1260 [07:37<00:29,  2.29it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  95%|█████████▍| 1194/1260 [07:38<00:27,  2.40it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  95%|█████████▍| 1195/1260 [07:38<00:26,  2.43it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  95%|█████████▍| 1196/1260 [07:38<00:25,  2.49it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  95%|█████████▌| 1197/1260 [07:39<00:24,  2.53it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  95%|█████████▌| 1198/1260 [07:39<00:24,  2.56it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  95%|█████████▌| 1199/1260 [07:40<00:23,  2.59it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  95%|█████████▌| 1200/1260 [07:40<00:22,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  95%|█████████▌| 1201/1260 [07:40<00:22,  2.60it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  95%|█████████▌| 1202/1260 [07:41<00:23,  2.46it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  95%|█████████▌| 1203/1260 [07:41<00:22,  2.53it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  96%|█████████▌| 1204/1260 [07:42<00:22,  2.54it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  96%|█████████▌| 1205/1260 [07:42<00:21,  2.55it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  96%|█████████▌| 1206/1260 [07:42<00:21,  2.56it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  96%|█████████▌| 1207/1260 [07:43<00:20,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  96%|█████████▌| 1208/1260 [07:43<00:19,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  96%|█████████▌| 1209/1260 [07:43<00:19,  2.57it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  96%|█████████▌| 1210/1260 [07:44<00:19,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  96%|█████████▌| 1211/1260 [07:44<00:18,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  96%|█████████▌| 1212/1260 [07:45<00:18,  2.59it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  96%|█████████▋| 1213/1260 [07:45<00:17,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  96%|█████████▋| 1214/1260 [07:45<00:17,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  96%|█████████▋| 1215/1260 [07:46<00:16,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  97%|█████████▋| 1216/1260 [07:46<00:16,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  97%|█████████▋| 1217/1260 [07:46<00:16,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  97%|█████████▋| 1218/1260 [07:47<00:15,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  97%|█████████▋| 1219/1260 [07:47<00:15,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  97%|█████████▋| 1220/1260 [07:48<00:15,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  97%|█████████▋| 1221/1260 [07:48<00:14,  2.67it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  97%|█████████▋| 1222/1260 [07:48<00:14,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  97%|█████████▋| 1223/1260 [07:49<00:13,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  97%|█████████▋| 1224/1260 [07:49<00:13,  2.70it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  97%|█████████▋| 1225/1260 [07:49<00:13,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  97%|█████████▋| 1226/1260 [07:50<00:12,  2.68it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  97%|█████████▋| 1227/1260 [07:50<00:12,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  97%|█████████▋| 1228/1260 [07:51<00:12,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  98%|█████████▊| 1229/1260 [07:51<00:11,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  98%|█████████▊| 1230/1260 [07:51<00:12,  2.42it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  98%|█████████▊| 1231/1260 [07:52<00:11,  2.50it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  98%|█████████▊| 1232/1260 [07:52<00:11,  2.54it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  98%|█████████▊| 1233/1260 [07:53<00:10,  2.54it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  98%|█████████▊| 1234/1260 [07:53<00:10,  2.51it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  98%|█████████▊| 1235/1260 [07:53<00:09,  2.55it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  98%|█████████▊| 1236/1260 [07:54<00:09,  2.60it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  98%|█████████▊| 1237/1260 [07:54<00:08,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  98%|█████████▊| 1238/1260 [07:54<00:08,  2.62it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  98%|█████████▊| 1239/1260 [07:55<00:07,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  98%|█████████▊| 1240/1260 [07:55<00:07,  2.63it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  98%|█████████▊| 1241/1260 [07:56<00:07,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  99%|█████████▊| 1242/1260 [07:56<00:06,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  99%|█████████▊| 1243/1260 [07:56<00:06,  2.66it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  99%|█████████▊| 1244/1260 [07:57<00:05,  2.69it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  99%|█████████▉| 1245/1260 [07:57<00:05,  2.65it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  99%|█████████▉| 1246/1260 [07:58<00:05,  2.58it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  99%|█████████▉| 1247/1260 [07:58<00:05,  2.55it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  99%|█████████▉| 1248/1260 [07:58<00:04,  2.57it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  99%|█████████▉| 1249/1260 [07:59<00:04,  2.53it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  99%|█████████▉| 1250/1260 [07:59<00:03,  2.59it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  99%|█████████▉| 1251/1260 [07:59<00:03,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  99%|█████████▉| 1252/1260 [08:00<00:03,  2.55it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t:  99%|█████████▉| 1253/1260 [08:00<00:02,  2.57it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t: 100%|█████████▉| 1254/1260 [08:01<00:02,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t: 100%|█████████▉| 1255/1260 [08:01<00:01,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t: 100%|█████████▉| 1256/1260 [08:01<00:01,  2.61it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t: 100%|█████████▉| 1257/1260 [08:02<00:01,  2.59it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t: 100%|█████████▉| 1258/1260 [08:02<00:00,  2.60it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t: 100%|█████████▉| 1259/1260 [08:03<00:00,  2.60it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# t: 100%|██████████| 1260/1260 [08:03<00:00,  2.64it/s, now=None]
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# now1
# 720
# (720, 1280)
# warped_bin_img.shape(720, 1280)
# out_img.shape(720, 1280, 3)
# Moviepy - Done !
# Moviepy - video ready project_video_output4.mp4
# CPU times: user 1h 10min 44s, sys: 2min 18s, total: 1h 13min 2s
# Wall time: 8min 4s
